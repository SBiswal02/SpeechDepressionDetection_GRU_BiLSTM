# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

import os
import sys
import glob
import pickle
import random

import tensorflow as tf
import tensorflow_hub as hub

from sklearn.model_selection import train_test_split
import librosa as lb
import parselmouth
from parselmouth.praat import call
# Out:
# 2025-08-12 23:13:44.705977: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-12 23:13:44.719745: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-12 23:13:44.839075: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-08-12 23:13:44.951853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755020625.045881    5778 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755020625.083390    5778 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755020625.312855    5778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755020625.312948    5778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755020625.312956    5778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755020625.312962    5778 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-12 23:13:45.343208: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Preprocessing
#
# > do on by one in concatenation
#
# > model on prosodic features

# %%
data_csv_path = '/home/smrutibiswal/Research/Dataset/labels/edited'

train_df = pd.read_csv(os.path.join(data_csv_path, 'train_split.csv'))
train_df = train_df[['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score']]

test_df = pd.read_csv(os.path.join(data_csv_path, 'dev_split.csv'))
test_df = test_df[['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score']]

print(f"Train set: {train_df.shape[0]} samples, Test set: {test_df.shape[0]} samples")
print("Training Samples: ")
print(train_df.head())
print("Testing Samples: ")
print(test_df.head())
# Out:
# Train set: 148 samples, Test set: 48 samples
# Training Samples:
#    Participant_ID   Gender  PHQ_Binary  PHQ_Score
# 0             302     male           0          4
# 1             303   female           0          0
# 2             304   female           0          6
# 3             305     male           0          7
# 4             307  female            0          4
# Testing Samples:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score
# 0             300    male           0          2
# 1             301    male           0          3
# 2             306  female           0          0
# 3             317    male           0          8
# 4             320  female           0         11

# %%
df = pd.concat([train_df, test_df], axis=0)
df = df.sort_values(by=['Participant_ID'])
df = df.reset_index(drop=True)
df.head()
# Out:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score
# 0             300    male           0          2
# 1             301    male           0          3
# 2             302    male           0          4
# 3             303  female           0          0
# 4             304  female           0          6

# %% [markdown]
# ## Features Df

# %%
# speech rate
speech_rate_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/speech_rate.csv')
speech_rate_df = speech_rate_df[['Participant_ID', 'Speech_Rate']]
speech_rate_df.head()

df['Speech_Rate'] = df['Participant_ID'].map(speech_rate_df.set_index('Participant_ID')['Speech_Rate'])
df.head()
# Out:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  Speech_Rate
# 0             300    male           0          2     0.423796
# 1             301    male           0          3     1.058485
# 2             302    male           0          4     0.625064
# 3             303  female           0          0     1.196229
# 4             304  female           0          6     0.868119

# %%
# for participant 300
participant_id = 300

############## Speech Rate
speech_rate = speech_rate_df[speech_rate_df['Participant_ID'] == participant_id]['Speech_Rate'].values[0]
print(f"Speech Rate for Participant {participant_id}: {speech_rate}")

############# Pauses
pause_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/pauses.csv')
pause_count = pause_df[pause_df['Participant_ID'] == participant_id]['Pauses'].values[0]
print(f"Pause Count for Participant {participant_id}: {pause_count}")
# Out:
# Speech Rate for Participant 300: 0.4237957357199261
# Pause Count for Participant 300: 949

# %%
############ Duration
duration_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Duration/300_duration.csv')
t = 0.25
duration_df.head()
mask = (duration_df['Start'] <= t) & (duration_df['End'] >= t)
result = duration_df[mask]
if not result.empty:
    result = 1
else:
    result = 0
print(f"Duration for Participant {participant_id} at time {t}: {result}")
# Out:
# Duration for Participant 300 at time 0.25: 0

# %%
def duration_value(duration_df, t):
    mask = (duration_df['Start'] <= t) & (duration_df['End'] > t)
    result = duration_df[mask]
    if not result.empty:
        return 1
    else:
        return 0

# %%
########### Pitch
pitch_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Pitch/300_pitch.csv')
pitch_df.head()
# Out:
#    Time  Pitch
# 0  0.00    NaN
# 1  0.01    NaN
# 2  0.02    NaN
# 3  0.03    NaN
# 4  0.04    NaN

# %%
t = 12.396
# t = 0.25
pitch_times = pitch_df['Time'].values

for i in range(len(pitch_times) - 1):
    if pitch_times[i] <= t < pitch_times[i + 1]:
        pitch_valu = pitch_df['Pitch'][i]
        break
    else:
        pitch_valu = None
print(f"Pitch for Participant {participant_id} at time {t}: {pitch_valu}")
# Out:
# Pitch for Participant 300 at time 12.396: 442.90377520305657

# %%
def pitch_value(pitch_df, t):
    pitch_times = pitch_df['Time'].values
    for i in range(len(pitch_times) - 1):
        if pitch_times[i] <= t < pitch_times[i + 1]:
            return pitch_df['Pitch'][i]
    return None

t = 12.396
pitch_val = pitch_value(pitch_df, t)
print(f"Pitch for Participant {participant_id} at time {t}: {pitch_val}")
# Out:
# Pitch for Participant 300 at time 12.396: 442.90377520305657

# %%
########## Loudness
loudness_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Loudness/300_loudness.csv')
loudness_df.head()
# Out:
#    LUFS_Loudness  LUFS_Time  RMS_Loudness  RMS_Times
# 0     -63.007661       0.00      0.007641       0.20
# 1     -63.424032       0.05      0.007191       0.25
# 2     -61.951871       0.10      0.006369       0.30
# 3     -60.765438       0.15      0.006127       0.35
# 4     -60.510343       0.20      0.006031       0.40

# %%
# lufs time start = LUFS_Time[i] end = LUFS_Time[i+1]
# rms time start = RMS_Times[i] - 0.2 end = RMS_Times[i]

t = 0.05
lufs_time = loudness_df['LUFS_Time'].values
rms_time = loudness_df['RMS_Times'].values
lufs_values = loudness_df['LUFS_Loudness'].values
rms_values = loudness_df['RMS_Loudness'].values

for i in range(len(lufs_time) - 1):
    if lufs_time[i] <= t < lufs_time[i + 1]:
        lufs_value = lufs_values[i]
        break
    else:
        lufs_value = None

for i in range(len(rms_time)):
    if rms_time[i] - 0.2 <= t < rms_time[i]:
        rms_value = rms_values[i]
        break
    else:
        rms_value = None
        
print(f"Loudness (LUFS) for Participant {participant_id} at time {t}: {lufs_value}")
print(f"Loudness (RMS) for Participant {participant_id} at time {t}: {rms_value}")
# Out:
# Loudness (LUFS) for Participant 300 at time 0.05: -63.42403189464935
# Loudness (RMS) for Participant 300 at time 0.05: 0.0076410277

# %%
def loudness_values(loudness_df, t):
    lufs_time = loudness_df['LUFS_Time'].values
    rms_time = loudness_df['RMS_Times'].values
    lufs_values = loudness_df['LUFS_Loudness'].values
    rms_values = loudness_df['RMS_Loudness'].values

    for i in range(len(lufs_time) - 1):
        if lufs_time[i] <= t < lufs_time[i + 1]:
            lufs_value = lufs_values[i]
            break
        else:
            lufs_value = None

    for i in range(len(rms_time)):
        if rms_time[i] - 0.2 <= t < rms_time[i]:
            rms_value = rms_values[i]
            break
        else:
            rms_value = None
            
    return lufs_value, rms_value

t = 0.05
lufs_value, rms_value = loudness_values(loudness_df, t)
print(f"Loudness (LUFS) for Participant {participant_id} at time {t}: {lufs_value}")
print(f"Loudness (RMS) for Participant {participant_id} at time {t}: {rms_value}")
# Out:
# Loudness (LUFS) for Participant 300 at time 0.05: -63.42403189464935
# Loudness (RMS) for Participant 300 at time 0.05: 0.0076410277

# %%
############ Rhythm
with open('/home/smrutibiswal/Research/ProsodyOnly/Rhythm/300_rhythm.pkl', 'rb') as f:
    rhythm_data = pickle.load(f)
rhythm_df = pd.DataFrame(rhythm_data)
rhythm_df.head()
# Out:
#    durations     types
# 0      12.37  unvoiced
# 1       0.05    voiced
# 2       1.14  unvoiced
# 3       0.04    voiced
# 4       7.03  unvoiced

# %%
duration_rhythm = rhythm_df['durations'].to_list()
rhythm_val = rhythm_df['types'].to_list()

segment_starts = np.cumsum([0] + duration_rhythm[:-1])
segment_ends = np.cumsum(duration_rhythm)

## find at t = 0.25 if voiced or unvoiced
t = 12.371
mask = (segment_starts <= t) & (segment_ends >= t)
if mask.any():
    index = np.where(mask)[0][0]
    segment_type = rhythm_val[index]
    print(f"Segment type at time {t}: {segment_type}")
else:
    print(f"No segment found at time {t}")

t = 12
for start, end, typ in zip(segment_starts, segment_ends, rhythm_val):
    if start <= t <= end:
        print(f"Segment type at time {t}: {typ}")
        break
else:
    print(f"No segment found at time {t}")
    
# # Find first "voiced" index
# for start, typ in zip(segment_starts, rhythm_val):
#     if typ.lower() == "voiced":
#         first_voiced_start = start
#         break

# print(f"First voiced section starts at {first_voiced_start:.3f} seconds")

t = (12.35 + 12.4) / 2
mask = (segment_starts <= t) & (segment_ends >= t)
if mask.any():
    index = np.where(mask)[0][0]
    segment_type = rhythm_val[index]
    print(f"Segment type at time {t}: {segment_type}")
else:
    print(f"No segment found at time {t}")
# t = 0.25 --- IGNORE ---
# Out:
# Segment type at time 12.371: voiced
# Segment type at time 12: unvoiced
# Segment type at time 12.375: voiced

# %%
def get_rhythm_value(rhythm_df, t):
    duration_rhythm = rhythm_df['durations'].to_list()
    rhythm_val = rhythm_df['types'].to_list()

    segment_starts = np.cumsum([0] + duration_rhythm[:-1])
    segment_ends = np.cumsum(duration_rhythm)

    mask = (segment_starts <= t) & (segment_ends >= t)
    if mask.any():
        index = np.where(mask)[0][0]
        segment_type = rhythm_val[index]
    else:
        segment_type = None

    if segment_type == "voiced":
        rhythm_value = 1
    elif segment_type == "unvoiced":
        rhythm_value = 0
    else:
        rhythm_value = None
        
    return segment_type, rhythm_value

t = 12.375
rhythm_value, rhythm_data = get_rhythm_value(rhythm_df, t)
print(f"Rhythm for Participant {participant_id} at time {t}: {rhythm_value}")
print(f"Rhythm Data for Participant {participant_id} at time {t}: {rhythm_data}")
# Out:
# Rhythm for Participant 300 at time 12.375: voiced
# Rhythm Data for Participant 300 at time 12.375: 1

# %%
############ Into############ Intonation
intonation_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Intonation/300_intonation.csv')
intonation_df.head()
# Out:
#    start_time  end_time label
# 0        0.00      0.10  flat
# 1        0.05      0.15  flat
# 2        0.10      0.20  flat
# 3        0.15      0.25  flat
# 4        0.20      0.30  flat

# %%
t = 69.15
mask = (intonation_df['start_time'] <= t) & (intonation_df['end_time'] > t)
if mask.any():
    index = np.where(mask)[0][0]
    label = intonation_df['label'].values[index]
    print(f"Intonation label at time {t}: {label}")
    
first_rising_row = intonation_df[intonation_df['label'].str.lower() == 'rising'].iloc[0]
first_rising_start = first_rising_row['start_time']
first_rising_end = first_rising_row['end_time']
print(f"First rising: {first_rising_start:.3f}s → {first_rising_end:.3f}s")
# Out:
# Intonation label at time 69.15: rising
# First rising: 69.100s → 69.200s

# %%
def intonation_values(intonation_df, t):
    mask = (intonation_df['start_time'] <= t) & (intonation_df['end_time'] > t)
    if mask.any():
        index = np.where(mask)[0][0]
        label = intonation_df['label'].values[index]
    else:
        label = None

    if label == "rising":
        intonation_value = 1
    elif label == "falling":
        intonation_value = -1
    elif label == "flat":
        intonation_value = 0
    else:
        intonation_value = None
        
    return label, intonation_value

t = 69.15
intonation_label, intonation_value = intonation_values(intonation_df, t)
print(f"Intonation label at time {t}: {intonation_label}")
print(f"Intonation value at time {t}: {intonation_value}")
# Out:
# Intonation label at time 69.15: rising
# Intonation value at time 69.15: 1

# %%
########### Stress
with open('/home/smrutibiswal/Research/ProsodyOnly/Stress/300_stress.pkl', 'rb') as f:
    stress_data = pickle.load(f)
stress_times = stress_data['stress_times']
isi = stress_data['isi']

print(f"Stress times: {stress_times}")
# Out:
# Stress times: [  1.12   1.13   1.14 ... 648.46 648.47 648.48]

# %%
def stress_values(stress_times, start, end):
    stress_times = np.array(stress_times)
    return 1 if np.any((stress_times >= start) & (stress_times <= end)) else 0

flag = stress_values(stress_times, 1.1, 1.2)
print(f"Stress flag for window 1.1–1.2: {flag}")
# Out:
# Stress flag for window 1.1–1.2: 1

# %%
############ jitter and shimmer
jitter_shimmer_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Jitter_and_Shimmer/300_jitter_shimmer.csv')
jitter_shimmer_df.head()
# Out:
#    start_time  end_time  jitter_local  shimmer_local
# 0        0.00      0.10           NaN            NaN
# 1        0.05      0.15           NaN            NaN
# 2        0.10      0.20      0.095974       0.137761
# 3        0.15      0.25           NaN            NaN
# 4        0.20      0.30      0.174204       0.256196

# %%
def jitter_value(jitter_shimmer_df, t):
    mask = (jitter_shimmer_df['start_time'] <= t) & (jitter_shimmer_df['end_time'] > t)
    if mask.any():
        index = np.where(mask)[0][0]
        return jitter_shimmer_df['jitter_local'].values[index]
    else:
        return None
    
t = 0.24
jitter_value_at_t = jitter_value(jitter_shimmer_df, t)
print(f"Jitter value at time {t}: {jitter_value_at_t}")
# Out:
# Jitter value at time 0.24: nan

# %%
def shimmer_value(jitter_shimmer_df, t):
    mask = (jitter_shimmer_df['start_time'] <= t) & (jitter_shimmer_df['end_time'] > t)
    if mask.any():
        index = np.where(mask)[0][0]
        return jitter_shimmer_df['shimmer_local'].values[index]
    else:
        return None

t = 0.24
shimmer_value_at_t = shimmer_value(jitter_shimmer_df, t)
print(f"Shimmer value at time {t}: {shimmer_value_at_t}")
# Out:
# Shimmer value at time 0.24: nan

# %%
def jitter_shimmer_values(jitter_shimmer_df, t):
    mask = (jitter_shimmer_df['start_time'] <= t) & (jitter_shimmer_df['end_time'] > t)
    if mask.any():
        index = np.where(mask)[0][0]
        jitter_value = jitter_shimmer_df['jitter_local'].values[index]
        shimmer_value = jitter_shimmer_df['shimmer_local'].values[index]
        return jitter_value, shimmer_value
    else:
        return None, None
    
t = 0.24
jitter_value, shimmer_value = jitter_shimmer_values(jitter_shimmer_df, t)
print(f"At time {t}: Jitter = {jitter_value}, Shimmer = {shimmer_value}")
# Out:
# At time 0.24: Jitter = nan, Shimmer = nan

# %%
############ HNR
hnr_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/HNR/300_hnr.csv')
hnr_df.head()
# Out:
#    start_time  HNR_Mean  HNR_Values  \
# 0        0.00  0.718931    0.090787
# 1        0.05  0.718931   -1.107589
# 2        0.10  0.718931    4.853599
# 3        0.15  0.718931   -0.612881
# 4        0.20  0.718931    2.977730
#
#                                           HNR Object
# 0  Object type: Harmonicity\nObject name: <no nam...
# 1  Object type: Harmonicity\nObject name: <no nam...
# 2  Object type: Harmonicity\nObject name: <no nam...
# 3  Object type: Harmonicity\nObject name: <no nam...
# 4  Object type: Harmonicity\nObject name: <no nam...

# %%
# t > start_time[i] and t < start_time[i+1]

def get_hnr_at_time(df, t):
    start_times = df['start_time'].values
    hnr_values = df['HNR_Values'].values

    for i in range(len(start_times) - 1):
        if start_times[i] <= t < start_times[i + 1]:
            return hnr_values[i]
    # If t is beyond the last range, return last value
    return hnr_values[-1]

# Example usage
t = 0.15
hnr_value = get_hnr_at_time(hnr_df, t)
print(f"HNR at time {t}: {hnr_value}")
# Out:
# HNR at time 0.15: -0.6128807250333956

# %%
############ Formant Analysis
formant_df = pd.read_csv('/home/smrutibiswal/Research/ProsodyOnly/Formants/300_formants.csv')
formant_df.head()
# Out:
#     Time           F1           F2           F3
# 0  0.025   750.407468  2150.493293  3180.244736
# 1  0.075   883.361327  2078.702020  2842.813306
# 2  0.125   750.652271  2024.704057  2965.434562
# 3  0.175  1163.625160  2263.589045  3269.664792
# 4  0.225   716.475058  2113.112182  3235.028391

# %%
t = 0.15
times = formant_df['Time'].values
formant1 = formant_df['F1'].values
formant2 = formant_df['F2'].values
formant3 = formant_df['F3'].values

for i in range(len(times) - 1):
    if times[i] <= t < times[i + 1]:
        f1_value = formant1[i]
        f2_value = formant2[i]
        f3_value = formant3[i]
        break
    else:
        f1_value = None
        f2_value = None
        f3_value = None
print(f"Formant values at time {t}: F1={f1_value}, F2={f2_value}, F3={f3_value}")
# Out:
# Formant values at time 0.15: F1=750.6522711722112, F2=2024.7040570318445, F3=2965.4345622048486

# %%
def formant_values(formant_df, t):
    times = formant_df['Time'].values
    formant1 = formant_df['F1'].values
    formant2 = formant_df['F2'].values
    formant3 = formant_df['F3'].values

    for i in range(len(times) - 1):
        if times[i] <= t < times[i + 1]:
            f1_value = formant1[i]
            f2_value = formant2[i]
            f3_value = formant3[i]
            return f1_value, f2_value, f3_value
    return None, None, None

t = 0.15
f1_value, f2_value, f3_value = formant_values(formant_df, t)
print(f"Formant values at time {t}: F1={f1_value}, F2={f2_value}, F3={f3_value}")
# Out:
# Formant values at time 0.15: F1=750.6522711722112, F2=2024.7040570318445, F3=2965.4345622048486

# %%
############# Spectral Tilt
with open('/home/smrutibiswal/Research/ProsodyOnly/Spectral_Tilt/300_spectral_tilt.pkl', 'rb') as f:
    spectral_tilt_data = pickle.load(f)
spectral_tilt_df = pd.DataFrame(spectral_tilt_data)
spectral_tilt_df.head()
# Out:
#           0
# 0 -0.003864
# 1 -0.004339
# 2 -0.004763
# 3 -0.004596
# 4 -0.003851

# %%
#### print the shape of each feature
print(f"Speech Rate Shape: {speech_rate}")
print(f"Pause Count Shape: {pause_count}")
print(f"Duration Shape: {duration_df.shape}")
print(f"Pitch Shape: {pitch_df.shape}")
print(f"Loudness Shape: {loudness_df.shape}")
print(f"Rhythm Shape: {rhythm_df.shape}")
print(f"Intonation Shape: {intonation_df.shape}")
print(f"Stress Shape: {len(stress_times)}")
print(f"ISI Shape: {len(isi)}")
print(f"Jitter and Shimmer Shape: {jitter_shimmer_df.shape}")
print(f"HNR Shape: {hnr_df.shape}")
print(f"Formant Analysis Shape: {formant_df.shape}")
print(f"Spectral Tilt Shape: {spectral_tilt_df.shape}")
# Out:
# Speech Rate Shape: 0.4237957357199261
# Pause Count Shape: 949
# Duration Shape: (949, 3)
# Pitch Shape: (64850, 2)
# Loudness Shape: (12963, 4)
# Rhythm Shape: (788, 2)
# Intonation Shape: (12970, 3)
# Stress Shape: 19454
# ISI Shape: 19453
# Jitter and Shimmer Shape: (12969, 4)
# HNR Shape: (12969, 4)
# Formant Analysis Shape: (12970, 4)
# Spectral Tilt Shape: (20266, 1)

# %%
data_csv_path = '/home/smrutibiswal/Research/Dataset/labels/edited'

train_df = pd.read_csv(os.path.join(data_csv_path, 'train_split.csv'))
train_df = train_df[['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score']]

test_df = pd.read_csv(os.path.join(data_csv_path, 'dev_split.csv'))
test_df = test_df[['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score']]

print(f"Train set: {train_df.shape[0]} samples, Test set: {test_df.shape[0]} samples")
print("Training Samples: ")
print(train_df.head())
print("Testing Samples: ")
print(test_df.head())
# Out:
# Train set: 148 samples, Test set: 48 samples
# Training Samples:
#    Participant_ID   Gender  PHQ_Binary  PHQ_Score
# 0             302     male           0          4
# 1             303   female           0          0
# 2             304   female           0          6
# 3             305     male           0          7
# 4             307  female            0          4
# Testing Samples:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score
# 0             300    male           0          2
# 1             301    male           0          3
# 2             306  female           0          0
# 3             317    male           0          8
# 4             320  female           0         11

# %%
train_audio_path = '/home/smrutibiswal/Research/Dataset/data/train/audios'
test_audio_path = '/home/smrutibiswal/Research/Dataset/data/validation/audios'
train_trans_path = '/home/smrutibiswal/Research/Dataset/data/train/transcripts'
test_trans_path = '/home/smrutibiswal/Research/Dataset/data/validation/transcripts'
train_txt_path = '/home/smrutibiswal/Research/TextOnly/train'
test_txt_path = '/home/smrutibiswal/Research/TextOnly/test'

train_df['Audio_Path'] = ''
train_df['Transcript_Path'] = ''
train_df['Text_Path'] = ''
test_df['Audio_Path'] = ''
test_df['Transcript_Path'] = ''
test_df['Text_Path'] = ''


for i in range(train_df.shape[0]):
    audio_file = str(train_df['Participant_ID'][i]) + '_AUDIO.wav'
    train_df['Audio_Path'][i] = os.path.join(train_audio_path, audio_file)
    transcript_file = str(train_df['Participant_ID'][i])+'_TRANSCRIPT.csv'
    train_df['Transcript_Path'][i] = os.path.join(train_trans_path, transcript_file)
    txt_file = str(train_df['Participant_ID'][i])+'.txt'
    train_df['Text_Path'][i] = os.path.join(train_txt_path, txt_file)
    
    
for i in range(len(test_df)):
    audio_file = str(test_df['Participant_ID'][i]) + '_AUDIO.wav'
    test_df['Audio_Path'][i] = os.path.join(test_audio_path, audio_file)
    transcript_file = str(test_df['Participant_ID'][i])+'_TRANSCRIPT.csv'
    test_df['Transcript_Path'][i] = os.path.join(test_trans_path, transcript_file)
    txt_file = str(test_df['Participant_ID'][i])+'.txt'
    test_df['Text_Path'][i] = os.path.join(test_txt_path, txt_file)
    
train_df.head()
# Out:
#    Participant_ID   Gender  PHQ_Binary  PHQ_Score  \
# 0             302     male           0          4
# 1             303   female           0          0
# 2             304   female           0          6
# 3             305     male           0          7
# 4             307  female            0          4
#
#                                           Audio_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/train...
# 1  /home/smrutibiswal/Research/Dataset/data/train...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                      Transcript_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/train...
# 1  /home/smrutibiswal/Research/Dataset/data/train...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                            Text_Path
# 0  /home/smrutibiswal/Research/TextOnly/train/302...
# 1  /home/smrutibiswal/Research/TextOnly/train/303...
# 2  /home/smrutibiswal/Research/TextOnly/train/304...
# 3  /home/smrutibiswal/Research/TextOnly/train/305...
# 4  /home/smrutibiswal/Research/TextOnly/train/307...

# %%
df = pd.concat([train_df, test_df], axis=0)
df = df.sort_values(by=['Participant_ID'])
df = df.reset_index(drop=True)
df.head()
# Out:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  \
# 0             300    male           0          2
# 1             301    male           0          3
# 2             302    male           0          4
# 3             303  female           0          0
# 4             304  female           0          6
#
#                                           Audio_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/valid...
# 1  /home/smrutibiswal/Research/Dataset/data/valid...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                      Transcript_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/valid...
# 1  /home/smrutibiswal/Research/Dataset/data/valid...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                            Text_Path
# 0  /home/smrutibiswal/Research/TextOnly/test/300.txt
# 1  /home/smrutibiswal/Research/TextOnly/test/301.txt
# 2  /home/smrutibiswal/Research/TextOnly/train/302...
# 3  /home/smrutibiswal/Research/TextOnly/train/303...
# 4  /home/smrutibiswal/Research/TextOnly/train/304...

# %%
idx = df[df['Participant_ID'] == 300].index[0]
audio = df['Audio_Path'][idx]

# %%
# audio_length = lb.get_duration(filename=audio)
# print(audio_length)
# window_length = 400 # milliseconds
# hop_length = 50 # milliseconds

# feat = []

# for i in range(0, int(audio_length * 1000) - window_length, hop_length):
#     start = i / 1000.0
#     end = (i + window_length) / 1000.0
    
#     print(f"Processing window: {start:.3f} to {end:.3f} seconds")
    
#     speech_r = speech_rate
    
#     pause_c = pause_count
    
#     t_dur = start + end/2
#     duration_val = duration_value(duration_df, t_dur)
    
#     t_pitch = start + 0.01
#     pitch_val = pitch_value(pitch_df, t_pitch)
    
#     t_loudness = ((start+end)/2)+0.01
#     lufs_loudness, rms_loudness = loudness_values(loudness_df, t_loudness)
    
#     t_rhythm = (start + end) / 2
#     segment_type, rhythm_val = get_rhythm_value(rhythm_df, t_rhythm)
    
#     t_intonation = start + 0.01
#     intonation_label, intonation_val = intonation_values(intonation_df, t_intonation)

#     stress_val = stress_values(stress_times, start, end)
    
#     t_jitter_shimmer = start + 0.01
#     jitter_val, shimmer_val = jitter_shimmer_values(jitter_shimmer_df, t_jitter_shimmer)
    
#     t_hnr = start + 0.01
#     hnr_val = get_hnr_at_time(hnr_df, t_hnr)

#     t_formant = start + hop_length / 2 - 0.01
#     f1, f2, f3 = formant_values(formant_df, t_formant)
    
#     spectral_tilt = np.mean(spectral_tilt_df.values)
    
#     # concatenate all features horizontally
#     feature_vector = np.array([
#         speech_r, pause_c, duration_val, pitch_val, lufs_loudness,
#         rms_loudness, rhythm_val, intonation_val, stress_val,
#         jitter_val, shimmer_val, hnr_val, f1, f2, f3, spectral_tilt
#     ])
    
#     feat.append(feature_vector)
    
    
    
# print(f"Extracted features for {len(feat)} windows.")
# Out:
# 648.5
# Processing window: 0.000 to 0.400 seconds
# Processing window: 0.050 to 0.450 seconds
# Processing window: 0.100 to 0.500 seconds
# Processing window: 0.150 to 0.550 seconds
# Processing window: 0.200 to 0.600 seconds
# Processing window: 0.250 to 0.650 seconds
# Processing window: 0.300 to 0.700 seconds
# Processing window: 0.350 to 0.750 seconds
# Processing window: 0.400 to 0.800 seconds
# Processing window: 0.450 to 0.850 seconds
# Processing window: 0.500 to 0.900 seconds
# Processing window: 0.550 to 0.950 seconds
# Processing window: 0.600 to 1.000 seconds
# Processing window: 0.650 to 1.050 seconds
# Processing window: 0.700 to 1.100 seconds
# Processing window: 0.750 to 1.150 seconds
# Processing window: 0.800 to 1.200 seconds
# Processing window: 0.850 to 1.250 seconds
# Processing window: 0.900 to 1.300 seconds
# Processing window: 0.950 to 1.350 seconds
# Processing window: 1.000 to 1.400 seconds
# Processing window: 1.050 to 1.450 seconds
# Processing window: 1.100 to 1.500 seconds
# Processing window: 1.150 to 1.550 seconds
# Processing window: 1.200 to 1.600 seconds
# Processing window: 1.250 to 1.650 seconds
# Processing window: 1.300 to 1.700 seconds
# Processing window: 1.350 to 1.750 seconds
# Processing window: 1.400 to 1.800 seconds
# Processing window: 1.450 to 1.850 seconds
# Processing window: 1.500 to 1.900 seconds
# Processing window: 1.550 to 1.950 seconds
# Processing window: 1.600 to 2.000 seconds
# Processing window: 1.650 to 2.050 seconds
# Processing window: 1.700 to 2.100 seconds
# Processing window: 1.750 to 2.150 seconds
# Processing window: 1.800 to 2.200 seconds
# Processing window: 1.850 to 2.250 seconds
# Processing window: 1.900 to 2.300 seconds
# Processing window: 1.950 to 2.350 seconds
# Processing window: 2.000 to 2.400 seconds
# Processing window: 2.050 to 2.450 seconds
# Processing window: 2.100 to 2.500 seconds
# Processing window: 2.150 to 2.550 seconds
# Processing window: 2.200 to 2.600 seconds
# Processing window: 2.250 to 2.650 seconds
# Processing window: 2.300 to 2.700 seconds
# Processing window: 2.350 to 2.750 seconds
# Processing window: 2.400 to 2.800 seconds
# Processing window: 2.450 to 2.850 seconds
# Processing window: 2.500 to 2.900 seconds
# Processing window: 2.550 to 2.950 seconds
# Processing window: 2.600 to 3.000 seconds
# Processing window: 2.650 to 3.050 seconds
# Processing window: 2.700 to 3.100 seconds
# Processing window: 2.750 to 3.150 seconds
# Processing window: 2.800 to 3.200 seconds
# Processing window: 2.850 to 3.250 seconds
# Processing window: 2.900 to 3.300 seconds
# Processing window: 2.950 to 3.350 seconds
# Processing window: 3.000 to 3.400 seconds
# Processing window: 3.050 to 3.450 seconds
# Processing window: 3.100 to 3.500 seconds
# Processing window: 3.150 to 3.550 seconds
# Processing window: 3.200 to 3.600 seconds
# Processing window: 3.250 to 3.650 seconds
# Processing window: 3.300 to 3.700 seconds
# Processing window: 3.350 to 3.750 seconds
# Processing window: 3.400 to 3.800 seconds
# Processing window: 3.450 to 3.850 seconds
# Processing window: 3.500 to 3.900 seconds
# Processing window: 3.550 to 3.950 seconds
# Processing window: 3.600 to 4.000 seconds
# Processing window: 3.650 to 4.050 seconds
# Processing window: 3.700 to 4.100 seconds
# Processing window: 3.750 to 4.150 seconds
# Processing window: 3.800 to 4.200 seconds
# Processing window: 3.850 to 4.250 seconds
# Processing window: 3.900 to 4.300 seconds
# Processing window: 3.950 to 4.350 seconds
# Processing window: 4.000 to 4.400 seconds
# Processing window: 4.050 to 4.450 seconds
# Processing window: 4.100 to 4.500 seconds
# Processing window: 4.150 to 4.550 seconds
# Processing window: 4.200 to 4.600 seconds
# Processing window: 4.250 to 4.650 seconds
# Processing window: 4.300 to 4.700 seconds
# Processing window: 4.350 to 4.750 seconds
# Processing window: 4.400 to 4.800 seconds
# Processing window: 4.450 to 4.850 seconds
# Processing window: 4.500 to 4.900 seconds
# Processing window: 4.550 to 4.950 seconds
# Processing window: 4.600 to 5.000 seconds
# Processing window: 4.650 to 5.050 seconds
# Processing window: 4.700 to 5.100 seconds
# Processing window: 4.750 to 5.150 seconds
# Processing window: 4.800 to 5.200 seconds
# Processing window: 4.850 to 5.250 seconds
# Processing window: 4.900 to 5.300 seconds
# Processing window: 4.950 to 5.350 seconds
# Processing window: 5.000 to 5.400 seconds
# Processing window: 5.050 to 5.450 seconds
# Processing window: 5.100 to 5.500 seconds
# Processing window: 5.150 to 5.550 seconds
# Processing window: 5.200 to 5.600 seconds
# Processing window: 5.250 to 5.650 seconds
# Processing window: 5.300 to 5.700 seconds
# Processing window: 5.350 to 5.750 seconds
# Processing window: 5.400 to 5.800 seconds
# Processing window: 5.450 to 5.850 seconds
# Processing window: 5.500 to 5.900 seconds
# Processing window: 5.550 to 5.950 seconds
# Processing window: 5.600 to 6.000 seconds
# Processing window: 5.650 to 6.050 seconds
# Processing window: 5.700 to 6.100 seconds
# Processing window: 5.750 to 6.150 seconds
# Processing window: 5.800 to 6.200 seconds
# Processing window: 5.850 to 6.250 seconds
# Processing window: 5.900 to 6.300 seconds
# Processing window: 5.950 to 6.350 seconds
# Processing window: 6.000 to 6.400 seconds
# Processing window: 6.050 to 6.450 seconds
# Processing window: 6.100 to 6.500 seconds
# Processing window: 6.150 to 6.550 seconds
# Processing window: 6.200 to 6.600 seconds
# Processing window: 6.250 to 6.650 seconds
# Processing window: 6.300 to 6.700 seconds
# Processing window: 6.350 to 6.750 seconds
# Processing window: 6.400 to 6.800 seconds
# Processing window: 6.450 to 6.850 seconds
# Processing window: 6.500 to 6.900 seconds
# Processing window: 6.550 to 6.950 seconds
# Processing window: 6.600 to 7.000 seconds
# Processing window: 6.650 to 7.050 seconds
# Processing window: 6.700 to 7.100 seconds
# Processing window: 6.750 to 7.150 seconds
# Processing window: 6.800 to 7.200 seconds
# Processing window: 6.850 to 7.250 seconds
# Processing window: 6.900 to 7.300 seconds
# Processing window: 6.950 to 7.350 seconds
# Processing window: 7.000 to 7.400 seconds
# Processing window: 7.050 to 7.450 seconds
# Processing window: 7.100 to 7.500 seconds
# Processing window: 7.150 to 7.550 seconds
# Processing window: 7.200 to 7.600 seconds
# Processing window: 7.250 to 7.650 seconds
# Processing window: 7.300 to 7.700 seconds
# Processing window: 7.350 to 7.750 seconds
# Processing window: 7.400 to 7.800 seconds
# Processing window: 7.450 to 7.850 seconds
# Processing window: 7.500 to 7.900 seconds
# Processing window: 7.550 to 7.950 seconds
# Processing window: 7.600 to 8.000 seconds
# Processing window: 7.650 to 8.050 seconds
# Processing window: 7.700 to 8.100 seconds
# Processing window: 7.750 to 8.150 seconds
# Processing window: 7.800 to 8.200 seconds
# Processing window: 7.850 to 8.250 seconds
# Processing window: 7.900 to 8.300 seconds
# Processing window: 7.950 to 8.350 seconds
# Processing window: 8.000 to 8.400 seconds
# Processing window: 8.050 to 8.450 seconds
# Processing window: 8.100 to 8.500 seconds
# Processing window: 8.150 to 8.550 seconds
# Processing window: 8.200 to 8.600 seconds
# Processing window: 8.250 to 8.650 seconds
# Processing window: 8.300 to 8.700 seconds
# Processing window: 8.350 to 8.750 seconds
# Processing window: 8.400 to 8.800 seconds
# Processing window: 8.450 to 8.850 seconds
# Processing window: 8.500 to 8.900 seconds
# Processing window: 8.550 to 8.950 seconds
# Processing window: 8.600 to 9.000 seconds
# Processing window: 8.650 to 9.050 seconds
# Processing window: 8.700 to 9.100 seconds
# Processing window: 8.750 to 9.150 seconds
# Processing window: 8.800 to 9.200 seconds
# Processing window: 8.850 to 9.250 seconds
# Processing window: 8.900 to 9.300 seconds
# Processing window: 8.950 to 9.350 seconds
# Processing window: 9.000 to 9.400 seconds
# Processing window: 9.050 to 9.450 seconds
# Processing window: 9.100 to 9.500 seconds
# Processing window: 9.150 to 9.550 seconds
# Processing window: 9.200 to 9.600 seconds
# Processing window: 9.250 to 9.650 seconds
# Processing window: 9.300 to 9.700 seconds
# Processing window: 9.350 to 9.750 seconds
# Processing window: 9.400 to 9.800 seconds
# Processing window: 9.450 to 9.850 seconds
# Processing window: 9.500 to 9.900 seconds
# Processing window: 9.550 to 9.950 seconds
# Processing window: 9.600 to 10.000 seconds
# Processing window: 9.650 to 10.050 seconds
# Processing window: 9.700 to 10.100 seconds
# Processing window: 9.750 to 10.150 seconds
# Processing window: 9.800 to 10.200 seconds
# Processing window: 9.850 to 10.250 seconds
# Processing window: 9.900 to 10.300 seconds
# Processing window: 9.950 to 10.350 seconds
# Processing window: 10.000 to 10.400 seconds
# Processing window: 10.050 to 10.450 seconds
# Processing window: 10.100 to 10.500 seconds
# Processing window: 10.150 to 10.550 seconds
# Processing window: 10.200 to 10.600 seconds
# Processing window: 10.250 to 10.650 seconds
# Processing window: 10.300 to 10.700 seconds
# Processing window: 10.350 to 10.750 seconds
# Processing window: 10.400 to 10.800 seconds
# Processing window: 10.450 to 10.850 seconds
# Processing window: 10.500 to 10.900 seconds
# Processing window: 10.550 to 10.950 seconds
# Processing window: 10.600 to 11.000 seconds
# Processing window: 10.650 to 11.050 seconds
# Processing window: 10.700 to 11.100 seconds
# Processing window: 10.750 to 11.150 seconds
# Processing window: 10.800 to 11.200 seconds
# Processing window: 10.850 to 11.250 seconds
# Processing window: 10.900 to 11.300 seconds
# Processing window: 10.950 to 11.350 seconds
# Processing window: 11.000 to 11.400 seconds
# Processing window: 11.050 to 11.450 seconds
# Processing window: 11.100 to 11.500 seconds
# Processing window: 11.150 to 11.550 seconds
# Processing window: 11.200 to 11.600 seconds
# Processing window: 11.250 to 11.650 seconds
# Processing window: 11.300 to 11.700 seconds
# Processing window: 11.350 to 11.750 seconds
# Processing window: 11.400 to 11.800 seconds
# Processing window: 11.450 to 11.850 seconds
# Processing window: 11.500 to 11.900 seconds
# Processing window: 11.550 to 11.950 seconds
# Processing window: 11.600 to 12.000 seconds
# Processing window: 11.650 to 12.050 seconds
# Processing window: 11.700 to 12.100 seconds
# Processing window: 11.750 to 12.150 seconds
# Processing window: 11.800 to 12.200 seconds
# Processing window: 11.850 to 12.250 seconds
# Processing window: 11.900 to 12.300 seconds
# Processing window: 11.950 to 12.350 seconds
# Processing window: 12.000 to 12.400 seconds
# Processing window: 12.050 to 12.450 seconds
# Processing window: 15.800 to 16.200 seconds
# Processing window: 15.850 to 16.250 seconds
# Processing window: 15.900 to 16.300 seconds
# Processing window: 15.950 to 16.350 seconds
# Processing window: 16.000 to 16.400 seconds
# Processing window: 16.050 to 16.450 seconds
# Processing window: 16.100 to 16.500 seconds
# Processing window: 16.150 to 16.550 seconds
# Processing window: 16.200 to 16.600 seconds
# Processing window: 16.250 to 16.650 seconds
# Processing window: 16.300 to 16.700 seconds
# Processing window: 16.350 to 16.750 seconds
# Processing window: 16.400 to 16.800 seconds
# Processing window: 16.450 to 16.850 seconds
# Processing window: 16.500 to 16.900 seconds
# Processing window: 16.550 to 16.950 seconds
# Processing window: 16.600 to 17.000 seconds
# Processing window: 16.650 to 17.050 seconds
# Processing window: 16.700 to 17.100 seconds
# Processing window: 16.750 to 17.150 seconds
# Processing window: 16.800 to 17.200 seconds
# Processing window: 16.850 to 17.250 seconds
# Processing window: 16.900 to 17.300 seconds
# Processing window: 16.950 to 17.350 seconds
# Processing window: 17.000 to 17.400 seconds
# Processing window: 17.050 to 17.450 seconds
# Processing window: 17.100 to 17.500 seconds
# Processing window: 17.150 to 17.550 seconds
# Processing window: 17.200 to 17.600 seconds
# Processing window: 17.250 to 17.650 seconds
# Processing window: 17.300 to 17.700 seconds
# Processing window: 17.350 to 17.750 seconds
# Processing window: 17.400 to 17.800 seconds
# Processing window: 17.450 to 17.850 seconds
# Processing window: 17.500 to 17.900 seconds
# Processing window: 17.550 to 17.950 seconds
# Processing window: 17.600 to 18.000 seconds
# Processing window: 17.650 to 18.050 seconds
# Processing window: 17.700 to 18.100 seconds
# Processing window: 17.750 to 18.150 seconds
# Processing window: 17.800 to 18.200 seconds
# Processing window: 17.850 to 18.250 seconds
# Processing window: 17.900 to 18.300 seconds
# Processing window: 17.950 to 18.350 seconds
# Processing window: 18.000 to 18.400 seconds
# Processing window: 18.050 to 18.450 seconds
# Processing window: 18.100 to 18.500 seconds
# Processing window: 18.150 to 18.550 seconds
# Processing window: 18.200 to 18.600 seconds
# Processing window: 18.250 to 18.650 seconds
# Processing window: 18.300 to 18.700 seconds
# Processing window: 18.350 to 18.750 seconds
# Processing window: 18.400 to 18.800 seconds
# Processing window: 18.450 to 18.850 seconds
# Processing window: 18.500 to 18.900 seconds
# Processing window: 18.550 to 18.950 seconds
# Processing window: 18.600 to 19.000 seconds
# Processing window: 18.650 to 19.050 seconds
# Processing window: 18.700 to 19.100 seconds
# Processing window: 18.750 to 19.150 seconds
# Processing window: 18.800 to 19.200 seconds
# Processing window: 18.850 to 19.250 seconds
# Processing window: 18.900 to 19.300 seconds
# Processing window: 18.950 to 19.350 seconds
# Processing window: 19.000 to 19.400 seconds
# Processing window: 19.050 to 19.450 seconds
# Processing window: 19.100 to 19.500 seconds
# Processing window: 19.150 to 19.550 seconds
# Processing window: 19.200 to 19.600 seconds
# Processing window: 19.250 to 19.650 seconds
# Processing window: 19.300 to 19.700 seconds
# Processing window: 19.350 to 19.750 seconds
# Processing window: 19.400 to 19.800 seconds
# Processing window: 19.450 to 19.850 seconds
# Processing window: 19.500 to 19.900 seconds
# Processing window: 19.550 to 19.950 seconds
# Processing window: 19.600 to 20.000 seconds
# Processing window: 19.650 to 20.050 seconds
# Processing window: 19.700 to 20.100 seconds
# Processing window: 19.750 to 20.150 seconds
# Processing window: 19.800 to 20.200 seconds
# Processing window: 19.850 to 20.250 seconds
# Processing window: 19.900 to 20.300 seconds
# Processing window: 19.950 to 20.350 seconds
# Processing window: 20.000 to 20.400 seconds
# Processing window: 20.050 to 20.450 seconds
# Processing window: 20.100 to 20.500 seconds
# Processing window: 20.150 to 20.550 seconds
# Processing window: 20.200 to 20.600 seconds
# Processing window: 20.250 to 20.650 seconds
# Processing window: 20.300 to 20.700 seconds
# Processing window: 20.350 to 20.750 seconds
# Processing window: 20.400 to 20.800 seconds
# Processing window: 20.450 to 20.850 seconds
# Processing window: 20.500 to 20.900 seconds
# Processing window: 20.550 to 20.950 seconds
# Processing window: 20.600 to 21.000 seconds
# Processing window: 20.650 to 21.050 seconds
# Processing window: 20.700 to 21.100 seconds
# Processing window: 20.750 to 21.150 seconds
# Processing window: 20.800 to 21.200 seconds
# Processing window: 20.850 to 21.250 seconds
# Processing window: 20.900 to 21.300 seconds
# Processing window: 20.950 to 21.350 seconds
# Processing window: 21.000 to 21.400 seconds
# Processing window: 21.050 to 21.450 seconds
# Processing window: 21.100 to 21.500 seconds
# Processing window: 21.150 to 21.550 seconds
# Processing window: 21.200 to 21.600 seconds
# Processing window: 21.250 to 21.650 seconds
# Processing window: 21.300 to 21.700 seconds
# Processing window: 21.350 to 21.750 seconds
# Processing window: 21.400 to 21.800 seconds
# Processing window: 21.450 to 21.850 seconds
# Processing window: 21.500 to 21.900 seconds
# Processing window: 21.550 to 21.950 seconds
# Processing window: 21.600 to 22.000 seconds
# Processing window: 21.650 to 22.050 seconds
# Processing window: 21.700 to 22.100 seconds
# Processing window: 21.750 to 22.150 seconds
# Processing window: 21.800 to 22.200 seconds
# Processing window: 21.850 to 22.250 seconds
# Processing window: 21.900 to 22.300 seconds
# Processing window: 21.950 to 22.350 seconds
# Processing window: 22.000 to 22.400 seconds
# Processing window: 22.050 to 22.450 seconds
# Processing window: 22.100 to 22.500 seconds
# Processing window: 22.150 to 22.550 seconds
# Processing window: 22.200 to 22.600 seconds
# Processing window: 22.250 to 22.650 seconds
# Processing window: 22.300 to 22.700 seconds
# Processing window: 22.350 to 22.750 seconds
# Processing window: 22.400 to 22.800 seconds
# Processing window: 22.450 to 22.850 seconds
# Processing window: 22.500 to 22.900 seconds
# Processing window: 22.550 to 22.950 seconds
# Processing window: 22.600 to 23.000 seconds
# Processing window: 22.650 to 23.050 seconds
# Processing window: 22.700 to 23.100 seconds
# Processing window: 22.750 to 23.150 seconds
# Processing window: 22.800 to 23.200 seconds
# Processing window: 22.850 to 23.250 seconds
# Processing window: 22.900 to 23.300 seconds
# Processing window: 22.950 to 23.350 seconds
# Processing window: 23.000 to 23.400 seconds
# Processing window: 23.050 to 23.450 seconds
# Processing window: 23.100 to 23.500 seconds
# Processing window: 23.150 to 23.550 seconds
# Processing window: 34.300 to 34.700 seconds
# Processing window: 34.350 to 34.750 seconds
# Processing window: 34.400 to 34.800 seconds
# Processing window: 34.450 to 34.850 seconds
# Processing window: 34.500 to 34.900 seconds
# Processing window: 34.550 to 34.950 seconds
# Processing window: 34.600 to 35.000 seconds
# Processing window: 34.650 to 35.050 seconds
# Processing window: 34.700 to 35.100 seconds
# Processing window: 34.750 to 35.150 seconds
# Processing window: 34.800 to 35.200 seconds
# Processing window: 34.850 to 35.250 seconds
# Processing window: 34.900 to 35.300 seconds
# Processing window: 34.950 to 35.350 seconds
# Processing window: 35.000 to 35.400 seconds
# Processing window: 35.050 to 35.450 seconds
# Processing window: 35.100 to 35.500 seconds
# Processing window: 35.150 to 35.550 seconds
# Processing window: 35.200 to 35.600 seconds
# Processing window: 35.250 to 35.650 seconds
# Processing window: 35.300 to 35.700 seconds
# Processing window: 35.350 to 35.750 seconds
# Processing window: 35.400 to 35.800 seconds
# Processing window: 35.450 to 35.850 seconds
# Processing window: 35.500 to 35.900 seconds
# Processing window: 35.550 to 35.950 seconds
# Processing window: 35.600 to 36.000 seconds
# Processing window: 35.650 to 36.050 seconds
# Processing window: 35.700 to 36.100 seconds
# Processing window: 35.750 to 36.150 seconds
# Processing window: 35.800 to 36.200 seconds
# Processing window: 35.850 to 36.250 seconds
# Processing window: 35.900 to 36.300 seconds
# Processing window: 35.950 to 36.350 seconds
# Processing window: 36.000 to 36.400 seconds
# Processing window: 36.050 to 36.450 seconds
# Processing window: 36.100 to 36.500 seconds
# Processing window: 36.150 to 36.550 seconds
# Processing window: 36.200 to 36.600 seconds
# Processing window: 36.250 to 36.650 seconds
# Processing window: 36.300 to 36.700 seconds
# Processing window: 36.350 to 36.750 seconds
# Processing window: 36.400 to 36.800 seconds
# Processing window: 36.450 to 36.850 seconds
# Processing window: 36.500 to 36.900 seconds
# Processing window: 36.550 to 36.950 seconds
# Processing window: 36.600 to 37.000 seconds
# Processing window: 36.650 to 37.050 seconds
# Processing window: 36.700 to 37.100 seconds
# Processing window: 36.750 to 37.150 seconds
# Processing window: 36.800 to 37.200 seconds
# Processing window: 36.850 to 37.250 seconds
# Processing window: 36.900 to 37.300 seconds
# Processing window: 36.950 to 37.350 seconds
# Processing window: 37.000 to 37.400 seconds
# Processing window: 37.050 to 37.450 seconds
# Processing window: 37.100 to 37.500 seconds
# Processing window: 37.150 to 37.550 seconds
# Processing window: 37.200 to 37.600 seconds
# Processing window: 37.250 to 37.650 seconds
# Processing window: 37.300 to 37.700 seconds
# Processing window: 37.350 to 37.750 seconds
# Processing window: 37.400 to 37.800 seconds
# Processing window: 37.450 to 37.850 seconds
# Processing window: 37.500 to 37.900 seconds
# Processing window: 37.550 to 37.950 seconds
# Processing window: 37.600 to 38.000 seconds
# Processing window: 37.650 to 38.050 seconds
# Processing window: 37.700 to 38.100 seconds
# Processing window: 37.750 to 38.150 seconds
# Processing window: 37.800 to 38.200 seconds
# Processing window: 37.850 to 38.250 seconds
# Processing window: 37.900 to 38.300 seconds
# Processing window: 37.950 to 38.350 seconds
# Processing window: 38.000 to 38.400 seconds
# Processing window: 38.050 to 38.450 seconds
# Processing window: 38.100 to 38.500 seconds
# Processing window: 38.150 to 38.550 seconds
# Processing window: 38.200 to 38.600 seconds
# Processing window: 38.250 to 38.650 seconds
# Processing window: 38.300 to 38.700 seconds
# Processing window: 38.350 to 38.750 seconds
# Processing window: 38.400 to 38.800 seconds
# Processing window: 38.450 to 38.850 seconds
# Processing window: 38.500 to 38.900 seconds
# Processing window: 38.550 to 38.950 seconds
# Processing window: 38.600 to 39.000 seconds
# Processing window: 38.650 to 39.050 seconds
# Processing window: 38.700 to 39.100 seconds
# Processing window: 38.750 to 39.150 seconds
# Processing window: 38.800 to 39.200 seconds
# Processing window: 38.850 to 39.250 seconds
# Processing window: 38.900 to 39.300 seconds
# Processing window: 38.950 to 39.350 seconds
# Processing window: 39.000 to 39.400 seconds
# Processing window: 39.050 to 39.450 seconds
# Processing window: 39.100 to 39.500 seconds
# Processing window: 39.150 to 39.550 seconds
# Processing window: 39.200 to 39.600 seconds
# Processing window: 39.250 to 39.650 seconds
# Processing window: 39.300 to 39.700 seconds
# Processing window: 39.350 to 39.750 seconds
# Processing window: 39.400 to 39.800 seconds
# Processing window: 39.450 to 39.850 seconds
# Processing window: 39.500 to 39.900 seconds
# Processing window: 39.550 to 39.950 seconds
# Processing window: 39.600 to 40.000 seconds
# Processing window: 39.650 to 40.050 seconds
# Processing window: 39.700 to 40.100 seconds
# Processing window: 39.750 to 40.150 seconds
# Processing window: 39.800 to 40.200 seconds
# Processing window: 39.850 to 40.250 seconds
# Processing window: 39.900 to 40.300 seconds
# Processing window: 39.950 to 40.350 seconds
# Processing window: 40.000 to 40.400 seconds
# Processing window: 40.050 to 40.450 seconds
# Processing window: 40.100 to 40.500 seconds
# Processing window: 40.150 to 40.550 seconds
# Processing window: 40.200 to 40.600 seconds
# Processing window: 40.250 to 40.650 seconds
# Processing window: 40.300 to 40.700 seconds
# Processing window: 40.350 to 40.750 seconds
# Processing window: 40.400 to 40.800 seconds
# Processing window: 40.450 to 40.850 seconds
# Processing window: 40.500 to 40.900 seconds
# Processing window: 40.550 to 40.950 seconds
# Processing window: 40.600 to 41.000 seconds
# Processing window: 40.650 to 41.050 seconds
# Processing window: 40.700 to 41.100 seconds
# Processing window: 40.750 to 41.150 seconds
# Processing window: 40.800 to 41.200 seconds
# Processing window: 40.850 to 41.250 seconds
# Processing window: 40.900 to 41.300 seconds
# Processing window: 40.950 to 41.350 seconds
# Processing window: 41.000 to 41.400 seconds
# Processing window: 41.050 to 41.450 seconds
# Processing window: 41.100 to 41.500 seconds
# Processing window: 41.150 to 41.550 seconds
# Processing window: 41.200 to 41.600 seconds
# Processing window: 41.250 to 41.650 seconds
# Processing window: 41.300 to 41.700 seconds
# Processing window: 41.350 to 41.750 seconds
# Processing window: 41.400 to 41.800 seconds
# Processing window: 41.450 to 41.850 seconds
# Processing window: 41.500 to 41.900 seconds
# Processing window: 41.550 to 41.950 seconds
# Processing window: 41.600 to 42.000 seconds
# Processing window: 41.650 to 42.050 seconds
# Processing window: 41.700 to 42.100 seconds
# Processing window: 41.750 to 42.150 seconds
# Processing window: 41.800 to 42.200 seconds
# Processing window: 41.850 to 42.250 seconds
# Processing window: 41.900 to 42.300 seconds
# Processing window: 41.950 to 42.350 seconds
# Processing window: 42.000 to 42.400 seconds
# Processing window: 42.050 to 42.450 seconds
# Processing window: 42.100 to 42.500 seconds
# Processing window: 42.150 to 42.550 seconds
# Processing window: 42.200 to 42.600 seconds
# Processing window: 42.250 to 42.650 seconds
# Processing window: 42.300 to 42.700 seconds
# Processing window: 42.350 to 42.750 seconds
# Processing window: 42.400 to 42.800 seconds
# Processing window: 42.450 to 42.850 seconds
# Processing window: 42.500 to 42.900 seconds
# Processing window: 42.550 to 42.950 seconds
# Processing window: 42.600 to 43.000 seconds
# Processing window: 42.650 to 43.050 seconds
# Processing window: 42.700 to 43.100 seconds
# Processing window: 42.750 to 43.150 seconds
# Processing window: 42.800 to 43.200 seconds
# Processing window: 42.850 to 43.250 seconds
# Processing window: 42.900 to 43.300 seconds
# Processing window: 42.950 to 43.350 seconds
# Processing window: 43.000 to 43.400 seconds
# Processing window: 43.050 to 43.450 seconds
# Processing window: 43.100 to 43.500 seconds
# Processing window: 43.150 to 43.550 seconds
# Processing window: 43.200 to 43.600 seconds
# Processing window: 43.250 to 43.650 seconds
# Processing window: 43.300 to 43.700 seconds
# Processing window: 43.350 to 43.750 seconds
# Processing window: 43.400 to 43.800 seconds
# Processing window: 43.450 to 43.850 seconds
# Processing window: 43.500 to 43.900 seconds
# Processing window: 43.550 to 43.950 seconds
# Processing window: 43.600 to 44.000 seconds
# Processing window: 43.650 to 44.050 seconds
# Processing window: 43.700 to 44.100 seconds
# Processing window: 43.750 to 44.150 seconds
# Processing window: 43.800 to 44.200 seconds
# Processing window: 43.850 to 44.250 seconds
# Processing window: 43.900 to 44.300 seconds
# Processing window: 43.950 to 44.350 seconds
# Processing window: 44.000 to 44.400 seconds
# Processing window: 44.050 to 44.450 seconds
# Processing window: 44.100 to 44.500 seconds
# Processing window: 44.150 to 44.550 seconds
# Processing window: 44.200 to 44.600 seconds
# Processing window: 44.250 to 44.650 seconds
# Processing window: 44.300 to 44.700 seconds
# Processing window: 44.350 to 44.750 seconds
# Processing window: 44.400 to 44.800 seconds
# Processing window: 44.450 to 44.850 seconds
# Processing window: 44.500 to 44.900 seconds
# Processing window: 44.550 to 44.950 seconds
# Processing window: 44.600 to 45.000 seconds
# Processing window: 44.650 to 45.050 seconds
# Processing window: 44.700 to 45.100 seconds
# Processing window: 44.750 to 45.150 seconds
# Processing window: 44.800 to 45.200 seconds
# Processing window: 44.850 to 45.250 seconds
# Processing window: 44.900 to 45.300 seconds
# Processing window: 44.950 to 45.350 seconds
# Processing window: 45.000 to 45.400 seconds
# Processing window: 45.050 to 45.450 seconds
# Processing window: 45.100 to 45.500 seconds
# Processing window: 45.150 to 45.550 seconds
# Processing window: 45.200 to 45.600 seconds
# Processing window: 45.250 to 45.650 seconds
# Processing window: 45.300 to 45.700 seconds
# Processing window: 45.350 to 45.750 seconds
# Processing window: 49.100 to 49.500 seconds
# Processing window: 49.150 to 49.550 seconds
# Processing window: 49.200 to 49.600 seconds
# Processing window: 49.250 to 49.650 seconds
# Processing window: 49.300 to 49.700 seconds
# Processing window: 49.350 to 49.750 seconds
# Processing window: 49.400 to 49.800 seconds
# Processing window: 49.450 to 49.850 seconds
# Processing window: 49.500 to 49.900 seconds
# Processing window: 49.550 to 49.950 seconds
# Processing window: 49.600 to 50.000 seconds
# Processing window: 49.650 to 50.050 seconds
# Processing window: 49.700 to 50.100 seconds
# Processing window: 49.750 to 50.150 seconds
# Processing window: 49.800 to 50.200 seconds
# Processing window: 49.850 to 50.250 seconds
# Processing window: 49.900 to 50.300 seconds
# Processing window: 49.950 to 50.350 seconds
# Processing window: 50.000 to 50.400 seconds
# Processing window: 50.050 to 50.450 seconds
# Processing window: 50.100 to 50.500 seconds
# Processing window: 50.150 to 50.550 seconds
# Processing window: 50.200 to 50.600 seconds
# Processing window: 50.250 to 50.650 seconds
# Processing window: 50.300 to 50.700 seconds
# Processing window: 50.350 to 50.750 seconds
# Processing window: 50.400 to 50.800 seconds
# Processing window: 50.450 to 50.850 seconds
# Processing window: 50.500 to 50.900 seconds
# Processing window: 50.550 to 50.950 seconds
# Processing window: 50.600 to 51.000 seconds
# Processing window: 50.650 to 51.050 seconds
# Processing window: 50.700 to 51.100 seconds
# Processing window: 50.750 to 51.150 seconds
# Processing window: 50.800 to 51.200 seconds
# Processing window: 50.850 to 51.250 seconds
# Processing window: 50.900 to 51.300 seconds
# Processing window: 50.950 to 51.350 seconds
# Processing window: 51.000 to 51.400 seconds
# Processing window: 51.050 to 51.450 seconds
# Processing window: 51.100 to 51.500 seconds
# Processing window: 51.150 to 51.550 seconds
# Processing window: 51.200 to 51.600 seconds
# Processing window: 51.250 to 51.650 seconds
# Processing window: 51.300 to 51.700 seconds
# Processing window: 51.350 to 51.750 seconds
# Processing window: 51.400 to 51.800 seconds
# Processing window: 51.450 to 51.850 seconds
# Processing window: 51.500 to 51.900 seconds
# Processing window: 51.550 to 51.950 seconds
# Processing window: 51.600 to 52.000 seconds
# Processing window: 51.650 to 52.050 seconds
# Processing window: 51.700 to 52.100 seconds
# Processing window: 51.750 to 52.150 seconds
# Processing window: 51.800 to 52.200 seconds
# Processing window: 51.850 to 52.250 seconds
# Processing window: 51.900 to 52.300 seconds
# Processing window: 51.950 to 52.350 seconds
# Processing window: 52.000 to 52.400 seconds
# Processing window: 52.050 to 52.450 seconds
# Processing window: 52.100 to 52.500 seconds
# Processing window: 52.150 to 52.550 seconds
# Processing window: 52.200 to 52.600 seconds
# Processing window: 52.250 to 52.650 seconds
# Processing window: 52.300 to 52.700 seconds
# Processing window: 52.350 to 52.750 seconds
# Processing window: 52.400 to 52.800 seconds
# Processing window: 52.450 to 52.850 seconds
# Processing window: 52.500 to 52.900 seconds
# Processing window: 52.550 to 52.950 seconds
# Processing window: 52.600 to 53.000 seconds
# Processing window: 52.650 to 53.050 seconds
# Processing window: 52.700 to 53.100 seconds
# Processing window: 52.750 to 53.150 seconds
# Processing window: 636.000 to 636.400 seconds
# Processing window: 636.050 to 636.450 seconds
# Processing window: 636.100 to 636.500 seconds
# Processing window: 636.150 to 636.550 seconds
# Processing window: 636.200 to 636.600 seconds
# Processing window: 636.250 to 636.650 seconds
# Processing window: 636.300 to 636.700 seconds
# Processing window: 636.350 to 636.750 seconds
# Processing window: 636.400 to 636.800 seconds
# Processing window: 636.450 to 636.850 seconds
# Processing window: 636.500 to 636.900 seconds
# Processing window: 636.550 to 636.950 seconds
# Processing window: 636.600 to 637.000 seconds
# Processing window: 636.650 to 637.050 seconds
# Processing window: 636.700 to 637.100 seconds
# Processing window: 636.750 to 637.150 seconds
# Processing window: 636.800 to 637.200 seconds
# Processing window: 636.850 to 637.250 seconds
# Processing window: 636.900 to 637.300 seconds
# Processing window: 636.950 to 637.350 seconds
# Processing window: 637.000 to 637.400 seconds
# Processing window: 637.050 to 637.450 seconds
# Processing window: 637.100 to 637.500 seconds
# Processing window: 637.150 to 637.550 seconds
# Processing window: 637.200 to 637.600 seconds
# Processing window: 637.250 to 637.650 seconds
# Processing window: 637.300 to 637.700 seconds
# Processing window: 637.350 to 637.750 seconds
# Processing window: 637.400 to 637.800 seconds
# Processing window: 637.450 to 637.850 seconds
# Processing window: 637.500 to 637.900 seconds
# Processing window: 637.550 to 637.950 seconds
# Processing window: 637.600 to 638.000 seconds
# Processing window: 637.650 to 638.050 seconds
# Processing window: 637.700 to 638.100 seconds
# Processing window: 637.750 to 638.150 seconds
# Processing window: 637.800 to 638.200 seconds
# Processing window: 637.850 to 638.250 seconds
# Processing window: 637.900 to 638.300 seconds
# Processing window: 637.950 to 638.350 seconds
# Processing window: 638.000 to 638.400 seconds
# Processing window: 638.050 to 638.450 seconds
# Processing window: 638.100 to 638.500 seconds
# Processing window: 638.150 to 638.550 seconds
# Processing window: 638.200 to 638.600 seconds
# Processing window: 638.250 to 638.650 seconds
# Processing window: 638.300 to 638.700 seconds
# Processing window: 638.350 to 638.750 seconds
# Processing window: 638.400 to 638.800 seconds
# Processing window: 638.450 to 638.850 seconds
# Processing window: 638.500 to 638.900 seconds
# Processing window: 638.550 to 638.950 seconds
# Processing window: 638.600 to 639.000 seconds
# Processing window: 638.650 to 639.050 seconds
# Processing window: 638.700 to 639.100 seconds
# Processing window: 638.750 to 639.150 seconds
# Processing window: 638.800 to 639.200 seconds
# Processing window: 638.850 to 639.250 seconds
# Processing window: 638.900 to 639.300 seconds
# Processing window: 638.950 to 639.350 seconds
# Processing window: 639.000 to 639.400 seconds
# Processing window: 639.050 to 639.450 seconds
# Processing window: 639.100 to 639.500 seconds
# Processing window: 639.150 to 639.550 seconds
# Processing window: 639.200 to 639.600 seconds
# Processing window: 639.250 to 639.650 seconds
# Processing window: 639.300 to 639.700 seconds
# Processing window: 639.350 to 639.750 seconds
# Processing window: 639.400 to 639.800 seconds
# Processing window: 639.450 to 639.850 seconds
# Processing window: 639.500 to 639.900 seconds
# Processing window: 639.550 to 639.950 seconds
# Processing window: 639.600 to 640.000 seconds
# Processing window: 639.650 to 640.050 seconds
# Processing window: 647.100 to 647.500 seconds
# Processing window: 647.150 to 647.550 seconds
# Processing window: 647.200 to 647.600 seconds
# Processing window: 647.250 to 647.650 seconds
# Processing window: 647.300 to 647.700 seconds
# Processing window: 647.350 to 647.750 seconds
# Processing window: 647.400 to 647.800 seconds
# Processing window: 647.450 to 647.850 seconds
# Processing window: 647.500 to 647.900 seconds
# Processing window: 647.550 to 647.950 seconds
# Processing window: 647.600 to 648.000 seconds
# Processing window: 647.650 to 648.050 seconds
# Processing window: 647.700 to 648.100 seconds
# Processing window: 647.750 to 648.150 seconds
# Processing window: 647.800 to 648.200 seconds
# Processing window: 647.850 to 648.250 seconds
# Processing window: 647.900 to 648.300 seconds
# Processing window: 647.950 to 648.350 seconds
# Processing window: 648.000 to 648.400 seconds
# Processing window: 648.050 to 648.450 seconds
# Extracted features for 12962 windows.

# %%
feat = np.array(feat)
print(f"Feature shape: {feat.shape}")
# Out:
# Feature shape: (12962, 16)

# %%
df['Prosodic_Features'] = ''
window_length = 400  # milliseconds
hop_length = 50  # milliseconds

if not os.path.exists('Prosodic_Features'):
    os.makedirs('Prosodic_Features')


for i in range(len(df)):
    feature_file = os.path.join('Prosodic_Features', f'{df["Participant_ID"][i]}_features.pkl')
    if not os.path.exists(feature_file):
        speech_rate = speech_rate_df[speech_rate_df['Participant_ID'] == participant_id]['Speech_Rate'].values[0]
        pause_count = pause_df[pause_df['Participant_ID'] == participant_id]['Pauses'].values[0]
        duration_path = f'Duration/{participant_id}_duration.csv'
        duration_df = pd.read_csv(duration_path)
        pitch_path = f'Pitch/{participant_id}_pitch.csv'
        pitch_df = pd.read_csv(pitch_path)
        loudness_path = f'Loudness/{participant_id}_loudness.csv'
        loudness_df = pd.read_csv(loudness_path)
        rhythm_path = f'Rhythm/{participant_id}_rhythm.pkl'
        with open(rhythm_path, 'rb') as f:
            rhythm_data = pickle.load(f)
        rhythm_df = pd.DataFrame(rhythm_data)
        intonation_path = f'Intonation/{participant_id}_intonation.csv'
        intonation_df = pd.read_csv(intonation_path)
        stress_path = f'Stress/{participant_id}_stress.pkl'
        with open(stress_path, 'rb') as f:
            stress_data = pickle.load(f)
        stress_times = stress_data['stress_times']
        isi = stress_data['isi']
        jitter_shimmer_path = f'Jitter_and_Shimmer/{participant_id}_jitter_shimmer.csv'
        jitter_shimmer_df = pd.read_csv(jitter_shimmer_path)
        hnr_path = f'HNR/{participant_id}_hnr.csv'
        hnr_df = pd.read_csv(hnr_path)
        formant_path = f'Formants/{participant_id}_formants.csv'
        formant_df = pd.read_csv(formant_path)
        spectral_tilt_path = f'Spectral_Tilt/{participant_id}_spectral_tilt.pkl'
        with open(spectral_tilt_path, 'rb') as f:
            spectral_tilt_data = pickle.load(f)
        spectral_tilt_df = pd.DataFrame(spectral_tilt_data)

        audio_length = lb.get_duration(filename=df['Audio_Path'][i])

        feat = []

        for j in range(0, int(audio_length * 1000) - window_length, hop_length):
            start = j / 1000.0
            end = (j + window_length) / 1000.0

            speech_r = speech_rate
            pause_c = pause_count

            t_dur = start + end / 2
            duration_val = duration_value(duration_df, t_dur)

            t_pitch = start + 0.01
            pitch_val = pitch_value(pitch_df, t_pitch)

            t_loudness = ((start + end) / 2) + 0.01
            lufs_loudness, rms_loudness = loudness_values(loudness_df, t_loudness)

            t_rhythm = (start + end) / 2
            segment_type, rhythm_val = get_rhythm_value(rhythm_df, t_rhythm)

            t_intonation = start + 0.01
            intonation_label, intonation_val = intonation_values(intonation_df, t_intonation)

            stress_val = stress_values(stress_times, start, end)

            t_jitter_shimmer = start + 0.01
            jitter_val, shimmer_val = jitter_shimmer_values(jitter_shimmer_df, t_jitter_shimmer)

            t_hnr = start + 0.01
            hnr_val = get_hnr_at_time(hnr_df, t_hnr)

            t_formant = start + hop_length / 2 - 0.01
            f1, f2, f3 = formant_values(formant_df, t_formant)

            spectral_tilt = np.mean(spectral_tilt_df.values)

            feature_vector = np.array([
                speech_r, pause_c, duration_val, pitch_val, lufs_loudness,
                rms_loudness, rhythm_val, intonation_val, stress_val,
                jitter_val, shimmer_val, hnr_val, f1, f2, f3, spectral_tilt
            ])

            feat.append(feature_vector)

        feat = np.array(feat)
        df['Prosodic_Features'][i] = feat

        # save the file 
        with open(feature_file, 'wb') as f:
            pickle.dump(feat, f)
    else:
        with open(os.path.join('Prosodic_Features', f'{df["Participant_ID"][i]}_features.pkl'), 'rb') as f:
            feat = pickle.load(f)
        df['Prosodic_Features'][i] = feat
        
            
    print(f"Extracted features for {len(feat)} windows for Participant {df['Participant_ID'][i]}.")
# Out:
# Extracted features for 12962 windows for Participant 300.
# Extracted features for 16470 windows for Participant 301.
# Extracted features for 15168 windows for Participant 302.
# Extracted features for 19698 windows for Participant 303.
# Extracted features for 15844 windows for Participant 304.
# Extracted features for 34072 windows for Participant 305.
# Extracted features for 17154 windows for Participant 306.
# Extracted features for 24768 windows for Participant 307.
# Extracted features for 17344 windows for Participant 308.
# Extracted features for 14108 windows for Participant 309.
# Extracted features for 16890 windows for Participant 310.
# Extracted features for 15704 windows for Participant 311.
# Extracted features for 15792 windows for Participant 312.
# Extracted features for 15068 windows for Participant 313.
# Extracted features for 30926 windows for Participant 314.
# Extracted features for 19500 windows for Participant 315.
# Extracted features for 17372 windows for Participant 316.
# Extracted features for 16090 windows for Participant 317.
# Extracted features for 11760 windows for Participant 318.
# Extracted features for 13586 windows for Participant 319.
# Extracted features for 16806 windows for Participant 320.
# Extracted features for 16430 windows for Participant 321.
# Extracted features for 20934 windows for Participant 322.
# Extracted features for 16732 windows for Participant 323.
# Extracted features for 14418 windows for Participant 324.
# Extracted features for 17492 windows for Participant 325.
# Extracted features for 13976 windows for Participant 326.
# Extracted features for 13608 windows for Participant 327.
# Extracted features for 21296 windows for Participant 328.
# Extracted features for 14118 windows for Participant 329.
# Extracted features for 15422 windows for Participant 330.
# Extracted features for 17006 windows for Participant 331.
# Extracted features for 17474 windows for Participant 332.
# Extracted features for 19378 windows for Participant 333.
# Extracted features for 19592 windows for Participant 334.
# Extracted features for 16594 windows for Participant 335.
# Extracted features for 18882 windows for Participant 336.
# Extracted features for 37416 windows for Participant 337.
# Extracted features for 11928 windows for Participant 338.
# Extracted features for 17250 windows for Participant 339.
# Extracted features for 11978 windows for Participant 340.
# Extracted features for 17342 windows for Participant 341.
# Extracted features for 18538 windows for Participant 343.
# Extracted features for 21802 windows for Participant 344.
# Extracted features for 15870 windows for Participant 345.
# Extracted features for 24428 windows for Participant 346.
# Extracted features for 12224 windows for Participant 347.
# Extracted features for 14380 windows for Participant 348.
# Extracted features for 24312 windows for Participant 349.
# Extracted features for 17628 windows for Participant 350.
# Extracted features for 15384 windows for Participant 351.
# Extracted features for 15194 windows for Participant 352.
# Extracted features for 15712 windows for Participant 353.
# Extracted features for 11528 windows for Participant 354.
# Extracted features for 13486 windows for Participant 355.
# Extracted features for 19072 windows for Participant 356.
# Extracted features for 8288 windows for Participant 357.
# Extracted features for 12950 windows for Participant 358.
# Extracted features for 20664 windows for Participant 359.
# Extracted features for 8800 windows for Participant 360.
# Extracted features for 12830 windows for Participant 361.
# Extracted features for 11796 windows for Participant 362.
# Extracted features for 24534 windows for Participant 363.
# Extracted features for 35622 windows for Participant 364.
# Extracted features for 27714 windows for Participant 365.
# Extracted features for 26246 windows for Participant 366.
# Extracted features for 32732 windows for Participant 367.
# Extracted features for 27088 windows for Participant 368.
# Extracted features for 20814 windows for Participant 369.
# Extracted features for 24164 windows for Participant 370.
# Extracted features for 18226 windows for Participant 371.
# Extracted features for 30266 windows for Participant 372.
# Extracted features for 25294 windows for Participant 373.
# Extracted features for 25746 windows for Participant 374.
# Extracted features for 12416 windows for Participant 375.
# Extracted features for 20506 windows for Participant 376.
# Extracted features for 26558 windows for Participant 377.
# Extracted features for 17460 windows for Participant 378.
# Extracted features for 20034 windows for Participant 379.
# Extracted features for 39316 windows for Participant 380.
# Extracted features for 21778 windows for Participant 381.
# Extracted features for 16476 windows for Participant 382.
# Extracted features for 27374 windows for Participant 383.
# Extracted features for 21128 windows for Participant 384.
# Extracted features for 10718 windows for Participant 385.
# Extracted features for 20780 windows for Participant 386.
# Extracted features for 12048 windows for Participant 387.
# Extracted features for 16616 windows for Participant 388.
# Extracted features for 19056 windows for Participant 389.
# Extracted features for 27126 windows for Participant 390.
# Extracted features for 13594 windows for Participant 391.
# Extracted features for 13106 windows for Participant 392.
# Extracted features for 12592 windows for Participant 393.
# Extracted features for 17776 windows for Participant 395.
# Extracted features for 15600 windows for Participant 396.
# Extracted features for 19058 windows for Participant 397.
# Extracted features for 14672 windows for Participant 399.
# Extracted features for 18726 windows for Participant 400.
# Extracted features for 18676 windows for Participant 401.
# Extracted features for 19102 windows for Participant 402.
# Extracted features for 17242 windows for Participant 403.
# Extracted features for 22604 windows for Participant 404.
# Extracted features for 31396 windows for Participant 405.
# Extracted features for 14428 windows for Participant 406.
# Extracted features for 25040 windows for Participant 407.
# Extracted features for 14310 windows for Participant 408.
# Extracted features for 20640 windows for Participant 409.
# Extracted features for 21292 windows for Participant 410.
# Extracted features for 27650 windows for Participant 411.
# Extracted features for 17130 windows for Participant 412.
# Extracted features for 19928 windows for Participant 413.
# Extracted features for 19678 windows for Participant 414.
# Extracted features for 15606 windows for Participant 415.
# Extracted features for 17308 windows for Participant 416.
# Extracted features for 17718 windows for Participant 417.
# Extracted features for 21776 windows for Participant 418.
# Extracted features for 18118 windows for Participant 419.
# Extracted features for 20970 windows for Participant 420.
# Extracted features for 16732 windows for Participant 421.
# Extracted features for 26684 windows for Participant 422.
# Extracted features for 19910 windows for Participant 423.
# Extracted features for 21246 windows for Participant 424.
# Extracted features for 23088 windows for Participant 425.
# Extracted features for 17128 windows for Participant 426.
# Extracted features for 17428 windows for Participant 427.
# Extracted features for 14074 windows for Participant 428.
# Extracted features for 19142 windows for Participant 429.
# Extracted features for 18168 windows for Participant 430.
# Extracted features for 16668 windows for Participant 431.
# Extracted features for 18710 windows for Participant 432.
# Extracted features for 16030 windows for Participant 433.
# Extracted features for 26390 windows for Participant 434.
# Extracted features for 23692 windows for Participant 435.
# Extracted features for 13750 windows for Participant 436.
# Extracted features for 16984 windows for Participant 437.
# Extracted features for 28590 windows for Participant 438.
# Extracted features for 25684 windows for Participant 439.
# Extracted features for 28274 windows for Participant 440.
# Extracted features for 19418 windows for Participant 441.
# Extracted features for 18992 windows for Participant 442.
# Extracted features for 14018 windows for Participant 443.
# Extracted features for 26202 windows for Participant 444.
# Extracted features for 14184 windows for Participant 445.
# Extracted features for 19960 windows for Participant 446.
# Extracted features for 16398 windows for Participant 447.
# Extracted features for 24252 windows for Participant 448.
# Extracted features for 20586 windows for Participant 449.
# Extracted features for 25496 windows for Participant 450.
# Extracted features for 23760 windows for Participant 451.
# Extracted features for 17774 windows for Participant 452.
# Extracted features for 20636 windows for Participant 453.
# Extracted features for 16074 windows for Participant 454.
# Extracted features for 15000 windows for Participant 455.
# Extracted features for 17646 windows for Participant 456.
# Extracted features for 19238 windows for Participant 457.
# Extracted features for 18986 windows for Participant 458.
# Extracted features for 19494 windows for Participant 459.
# Extracted features for 19622 windows for Participant 461.
# Extracted features for 19294 windows for Participant 462.
# Extracted features for 16686 windows for Participant 463.
# Extracted features for 19598 windows for Participant 464.
# Extracted features for 23260 windows for Participant 465.
# Extracted features for 31322 windows for Participant 466.
# Extracted features for 20040 windows for Participant 467.
# Extracted features for 18788 windows for Participant 468.
# Extracted features for 22524 windows for Participant 469.
# Extracted features for 19100 windows for Participant 470.
# Extracted features for 19898 windows for Participant 471.
# Extracted features for 18052 windows for Participant 472.
# Extracted features for 10658 windows for Participant 473.
# Extracted features for 18540 windows for Participant 474.
# Extracted features for 11736 windows for Participant 475.
# Extracted features for 12168 windows for Participant 476.
# Extracted features for 24886 windows for Participant 477.
# Extracted features for 18716 windows for Participant 478.
# Extracted features for 18200 windows for Participant 479.
# Extracted features for 17306 windows for Participant 480.
# Extracted features for 22320 windows for Participant 481.
# Extracted features for 20372 windows for Participant 482.
# Extracted features for 31532 windows for Participant 483.
# Extracted features for 19902 windows for Participant 484.
# Extracted features for 12046 windows for Participant 485.
# Extracted features for 13638 windows for Participant 486.
# Extracted features for 20462 windows for Participant 487.
# Extracted features for 17690 windows for Participant 488.
# Extracted features for 14086 windows for Participant 489.
# Extracted features for 13818 windows for Participant 490.
# Extracted features for 17626 windows for Participant 491.
# Extracted features for 18242 windows for Participant 492.
# Extracted features for 13983 windows for Participant 601.
# Extracted features for 26736 windows for Participant 603.
# Extracted features for 27675 windows for Participant 608.
# Extracted features for 18138 windows for Participant 612.
# Extracted features for 27273 windows for Participant 617.
# Extracted features for 27492 windows for Participant 627.
# Extracted features for 23290 windows for Participant 628.

# %%
# # start_idx is where participant id is 334
# start_idx = df[df['Participant_ID'] == 334].index[0]
# print(f"Start index for participant 334: {start_idx}")

# %%
# df['Prosodic_Features'] = ''
# window_length = 400  # milliseconds
# hop_length = 50  # milliseconds

# %%
# for i in range(0, start_idx):
#     with open(os.path.join('Prosodic_Features', f'{df["Participant_ID"][i]}_features.pkl'), 'rb') as f:
#         feat = pickle.load(f)
#     df['Prosodic_Features'][i] = feat
#     print(f"Loaded features for {df['Participant_ID'][i]} participant.")

# %%
# for i in range(start_idx, len(df)):
    
#     speech_rate = speech_rate_df[speech_rate_df['Participant_ID'] == participant_id]['Speech_Rate'].values[0]
#     pause_count = pause_df[pause_df['Participant_ID'] == participant_id]['Pauses'].values[0]
#     duration_path = f'Duration/{participant_id}_duration.csv'
#     duration_df = pd.read_csv(duration_path)
#     pitch_path = f'Pitch/{participant_id}_pitch.csv'
#     pitch_df = pd.read_csv(pitch_path)
#     loudness_path = f'Loudness/{participant_id}_loudness.csv'
#     loudness_df = pd.read_csv(loudness_path)
#     rhythm_path = f'Rhythm/{participant_id}_rhythm.pkl'
#     with open(rhythm_path, 'rb') as f:
#         rhythm_data = pickle.load(f)
#     rhythm_df = pd.DataFrame(rhythm_data)
#     intonation_path = f'Intonation/{participant_id}_intonation.csv'
#     intonation_df = pd.read_csv(intonation_path)
#     stress_path = f'Stress/{participant_id}_stress.pkl'
#     with open(stress_path, 'rb') as f:
#         stress_data = pickle.load(f)
#     stress_times = stress_data['stress_times']
#     isi = stress_data['isi']
#     jitter_shimmer_path = f'Jitter_and_Shimmer/{participant_id}_jitter_shimmer.csv'
#     jitter_shimmer_df = pd.read_csv(jitter_shimmer_path)
#     hnr_path = f'HNR/{participant_id}_hnr.csv'
#     hnr_df = pd.read_csv(hnr_path)
#     formant_path = f'Formants/{participant_id}_formants.csv'
#     formant_df = pd.read_csv(formant_path)
#     spectral_tilt_path = f'Spectral_Tilt/{participant_id}_spectral_tilt.pkl'
#     with open(spectral_tilt_path, 'rb') as f:
#         spectral_tilt_data = pickle.load(f)
#     spectral_tilt_df = pd.DataFrame(spectral_tilt_data)
    
#     audio_length = lb.get_duration(filename=df['Audio_Path'][i])
    
#     feat = []
    
#     for j in range(0, int(audio_length * 1000) - window_length, hop_length):
#         start = j / 1000.0
#         end = (j + window_length) / 1000.0
        
#         speech_r = speech_rate
#         pause_c = pause_count
        
#         t_dur = start + end / 2
#         duration_val = duration_value(duration_df, t_dur)
        
#         t_pitch = start + 0.01
#         pitch_val = pitch_value(pitch_df, t_pitch)
        
#         t_loudness = ((start + end) / 2) + 0.01
#         lufs_loudness, rms_loudness = loudness_values(loudness_df, t_loudness)
        
#         t_rhythm = (start + end) / 2
#         segment_type, rhythm_val = get_rhythm_value(rhythm_df, t_rhythm)
        
#         t_intonation = start + 0.01
#         intonation_label, intonation_val = intonation_values(intonation_df, t_intonation)

#         stress_val = stress_values(stress_times, start, end)
        
#         t_jitter_shimmer = start + 0.01
#         jitter_val, shimmer_val = jitter_shimmer_values(jitter_shimmer_df, t_jitter_shimmer)
        
#         t_hnr = start + 0.01
#         hnr_val = get_hnr_at_time(hnr_df, t_hnr)

#         t_formant = start + hop_length / 2 - 0.01
#         f1, f2, f3 = formant_values(formant_df, t_formant)
        
#         spectral_tilt = np.mean(spectral_tilt_df.values)
        
#         feature_vector = np.array([
#             speech_r, pause_c, duration_val, pitch_val, lufs_loudness,
#             rms_loudness, rhythm_val, intonation_val, stress_val,
#             jitter_val, shimmer_val, hnr_val, f1, f2, f3, spectral_tilt
#         ])
        
#         feat.append(feature_vector)
        
#     feat = np.array(feat)
#     # df['Prosodic_Features'][i] = feat
        
#     # save the file 
#     feature_file = os.path.join('Prosodic_Features', f'{df["Participant_ID"][i]}_features.pkl')
#     with open(feature_file, 'wb') as f:
#         pickle.dump(feat, f)
            
#     print(f"Extracted features for {len(feat)} windows for Participant {df['Participant_ID'][i]}.")

# %%
print(df.head())
# Out:
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  \
# 0             300    male           0          2
# 1             301    male           0          3
# 2             302    male           0          4
# 3             303  female           0          0
# 4             304  female           0          6
#
#                                           Audio_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/valid...
# 1  /home/smrutibiswal/Research/Dataset/data/valid...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                      Transcript_Path  \
# 0  /home/smrutibiswal/Research/Dataset/data/valid...
# 1  /home/smrutibiswal/Research/Dataset/data/valid...
# 2  /home/smrutibiswal/Research/Dataset/data/train...
# 3  /home/smrutibiswal/Research/Dataset/data/train...
# 4  /home/smrutibiswal/Research/Dataset/data/train...
#
#                                            Text_Path  \
# 0  /home/smrutibiswal/Research/TextOnly/test/300.txt
# 1  /home/smrutibiswal/Research/TextOnly/test/301.txt
# 2  /home/smrutibiswal/Research/TextOnly/train/302...
# 3  /home/smrutibiswal/Research/TextOnly/train/303...
# 4  /home/smrutibiswal/Research/TextOnly/train/304...
#
#                                    Prosodic_Features
# 0  [[0.4237957357199261, 949.0, 0.0, nan, -60.510...
# 1  [[0.4237957357199261, 949.0, 0.0, nan, -60.510...
# 2  [[0.4237957357199261, 949.0, 0.0, nan, -60.510...
# 3  [[0.4237957357199261, 949.0, 0.0, nan, -60.510...
# 4  [[0.4237957357199261, 949.0, 0.0, nan, -60.510...

# %%
# for i in range(len(df)):
#     with open(os.path.join('Prosodic_Features', f'{df["Participant_ID"][i]}_features.pkl'), 'rb') as f:
#         feat = pickle.load(f)
#     df['Prosodic_Features'][i] = feat
#     print(f"Loaded features for {df['Participant_ID'][i]} participant.")

# %%
# save df to csv
df.to_csv('prosodic_features_df.csv', index=False)

# %% [markdown]
# # Train Test Split

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# %%
print(type(df['Prosodic_Features'].iloc[0]))
# Out:
# <class 'numpy.ndarray'>

# %%
print(type(df['Prosodic_Features'][0]))
print(df['Prosodic_Features'][0])
# Out:
# <class 'numpy.ndarray'>
# [[0.4237957357199261 949.0 0.0 ... 2407.8997941624 2992.4913077169467
#   -0.002632039773451044]
#  [0.4237957357199261 949.0 0.0 ... 2126.476170659614 3363.5684497231546
#   -0.002632039773451044]
#  [0.4237957357199261 949.0 0.0 ... 2178.8526793924866 3361.139933425045
#   -0.002632039773451044]
#  ...
#  [np.float64(0.4237957357199261) np.int64(949) 0 ... None None
#   np.float64(-0.002632039773451044)]
#  [np.float64(0.4237957357199261) np.int64(949) 0 ... None None
#   np.float64(-0.002632039773451044)]
#  [np.float64(0.4237957357199261) np.int64(949) 0 ... None None
#   np.float64(-0.002632039773451044)]]

# %%
X = [np.nan_to_num(arr.astype(float), nan=0.0) for arr in df['Prosodic_Features']]
y = df['PHQ_Binary'].astype(int).values

print(len(X), X[0].shape, y.shape)
# Out:
# 196 (12962, 16) (196,)

# %%
max_len = max(seq.shape[0] for seq in X)  # longest sequence length
n_features = X[0].shape[1]
print(f"Max length: {max_len}, Number of features: {n_features}")

lengths = [seq.shape[0] for seq in X]
max_len = int(np.mean(lengths))  # round down to int
print(f"Average length: {max_len}")

X_pad = pad_sequences(X, maxlen=max_len, dtype='float32', padding='post')
print("Data shape:", X_pad.shape)
# Out:
# Max length: 39316, Number of features: 16
# Average length: 19275
# Data shape: (196, 19275, 16)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size=0.2, random_state=42, stratify=y)
print("Train set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)
# Out:
# Train set shape: (156, 19275, 16) (156,)
# Test set shape: (40, 19275, 16) (40,)

# %% [markdown]
# # Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout, Masking

# %% [markdown]
# ## CNN

# %%
n_features = X_pad.shape[2]

model = Sequential([
    Conv1D(64, kernel_size=3, activation='relu', input_shape=(max_len, n_features)),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(128, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(optimizer=Adam(learning_rate=0.01),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# 2025-08-12 23:15:50.909083: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 19273, 64)      │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 9636, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9636, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 9634, 128)      │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 4817, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 4817, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 616576)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │    39,460,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 39,488,833 (150.64 MB)
#  Trainable params: 39,488,833 (150.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 10
batch_size = 16
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 864ms/step - accuracy: 0.6210 - loss: 141245.5469 - val_accuracy: 0.7750 - val_loss: 5.5917
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 890ms/step - accuracy: 0.7764 - loss: 162.6868 - val_accuracy: 0.7750 - val_loss: 0.6793
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 788ms/step - accuracy: 0.7762 - loss: 3.5303 - val_accuracy: 0.7750 - val_loss: 0.6913
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 769ms/step - accuracy: 0.7457 - loss: 1.6052 - val_accuracy: 0.2250 - val_loss: 0.7060
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 772ms/step - accuracy: 0.6829 - loss: 0.9925 - val_accuracy: 0.2250 - val_loss: 0.7162
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 771ms/step - accuracy: 0.7373 - loss: 0.7808 - val_accuracy: 0.2250 - val_loss: 0.7202
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 841ms/step - accuracy: 0.7413 - loss: 0.7563 - val_accuracy: 0.2250 - val_loss: 0.7203
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 878ms/step - accuracy: 0.6812 - loss: 0.6086 - val_accuracy: 0.1750 - val_loss: 0.7324
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 842ms/step - accuracy: 0.7508 - loss: 0.6576 - val_accuracy: 0.1750 - val_loss: 0.7567
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 816ms/step - accuracy: 0.7058 - loss: 0.6003 - val_accuracy: 0.2000 - val_loss: 0.8937

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1958 - loss: 0.9084
# Test Loss: 0.8937, Test Accuracy: 0.2000

# %%
# save the model
if not os.path.exists('models'):
    os.makedirs('models')
model.save('models/prosody_cnn_10.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## BiLSTM

# %%
X = [np.nan_to_num(arr.astype(float), nan=0.0) for arr in df['Prosodic_Features']]
y = df['PHQ_Binary'].astype(int).values

print(len(X), X[0].shape, y.shape)

# %%
max_len = max(seq.shape[0] for seq in X)  # longest sequence length
n_features = X[0].shape[1]
print(f"Max length: {max_len}, Number of features: {n_features}")

lengths = [seq.shape[0] for seq in X]
max_len = int(np.mean(lengths))  # round down to int
print(f"Average length: {max_len}")

# minium length for padding
min_len = min(lengths)
print(f"Minimum length: {min_len}")

X_pad = pad_sequences(X, maxlen=min_len, dtype='float32', padding='post')
print("Data shape:", X_pad.shape)

X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size=0.2, random_state=42, stratify=y)
print("Train set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)
# Out:
# Max length: 39316, Number of features: 16
# Average length: 19275
# Minimum length: 8288
# Data shape: (196, 8288, 16)
# Train set shape: (156, 8288, 16) (156,)
# Test set shape: (40, 8288, 16) (40,)

# %%
n_timesteps = X_train.shape[1]
n_features = X_train.shape[2]

model = Sequential([
    Masking(mask_value=0.0, input_shape=(n_timesteps, n_features)),  # ignore padded zeros
    Bidirectional(LSTM(64, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(32)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')  # binary classification
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking (Masking)               │ (None, 8288, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 8288, 128)      │        41,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8288, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 64)             │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,801 (331.25 KB)
#  Trainable params: 84,801 (331.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 10
batch_size = 16

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/10
# 2025-08-12 23:20:02.469206: E tensorflow/core/util/util.cc:131] oneDNN supports DT_BOOL only on platforms with AVX-512. Falling back to the default Eigen-based implementation if present.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 81s 8s/step - accuracy: 0.5365 - loss: 0.6785 - val_accuracy: 0.7750 - val_loss: 0.5447
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 79s 8s/step - accuracy: 0.8080 - loss: 0.5140 - val_accuracy: 0.7750 - val_loss: 0.5346
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7677 - loss: 0.5361 - val_accuracy: 0.7750 - val_loss: 0.5369
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.8198 - loss: 0.4747 - val_accuracy: 0.7750 - val_loss: 0.5333
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7951 - loss: 0.5051 - val_accuracy: 0.7750 - val_loss: 0.5317
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7576 - loss: 0.5586 - val_accuracy: 0.7750 - val_loss: 0.5354
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.8304 - loss: 0.4611 - val_accuracy: 0.7750 - val_loss: 0.5395
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7513 - loss: 0.5562 - val_accuracy: 0.7750 - val_loss: 0.5365
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7647 - loss: 0.5562 - val_accuracy: 0.7750 - val_loss: 0.5366
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 80s 8s/step - accuracy: 0.7703 - loss: 0.5192 - val_accuracy: 0.7750 - val_loss: 0.5370

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# plot training history
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train_accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step - accuracy: 0.7771 - loss: 0.5335
# Test Loss: 0.5370, Test Accuracy: 0.7750

# %%
# save the model
model.save('models/prosody_lstm_10.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
